# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ["^GSPC", "^IXIC", "^GDAXI", "^N225"]
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source="yahoo", start="1997-1-2")["Adj Close"]

# %%
ind_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6009 entries, 1997-01-02 to 2020-11-13
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ^GSPC   6009 non-null   float64
#  1   ^IXIC   6009 non-null   float64
#  2   ^GDAXI  5898 non-null   float64
#  3   ^N225   5657 non-null   float64
# dtypes: float64(4)
# memory usage: 234.7 KB

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI         ^N225
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059           NaN
# 1997-01-03  748.030029  1310.680054  2863.260010           NaN
# 1997-01-06  747.650024  1316.400024  2890.199951  19446.000000
# 1997-01-07  753.229980  1327.729980  2876.340088  18896.189453
# 1997-01-08  748.409973  1320.349976  2904.080078  18680.380859

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI         ^N225
# Date
# 2020-11-09  3550.500000  11713.780273  13095.969727  24839.839844
# 2020-11-10  3545.530029  11553.860352  13163.110352  24905.589844
# 2020-11-11  3572.659912  11786.429688  13216.179688  25349.599609
# 2020-11-12  3537.010010  11709.589844  13052.950195  25520.880859
# 2020-11-13  3567.500000  11776.865234  13076.719727  25385.869141

# %%
(ind_data / ind_data.fillna(method='bfill', axis=0).iloc[0] * 100).plot(figsize=(15,6))

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.085122
# ^IXIC     0.124228
# ^GDAXI    0.077469
# ^N225    -0.001361
# dtype: float64
